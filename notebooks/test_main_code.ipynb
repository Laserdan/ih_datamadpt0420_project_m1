# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
sqlitedb_path = '../data/raw/raw_data_project_m1.db'

# %%
engine = create_engine(f'sqlite:///{sqlitedb_path}')

# %%
"""
----------------------------------------
"""
# Out:
# '\n----------------------------------------\n'

# %%
db_tables_names = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name", engine)
db_tables_names
# Out:
#             name
# 0    career_info
# 1   country_info
# 2  personal_info
# 3      poll_info

# %%
for table in db_tables_names['name']:
    print(table)
# Out:
# career_info
# country_info
# personal_info
# poll_info

# %%
"""
----------------------------------------
"""
# Out:
# '\n----------------------------------------\n'

# %%
personal_info_raw = pd.read_sql_query("SELECT * FROM personal_info", engine)
personal_info_raw.head()
# Out:
#                                    uuid           age gender dem_has_children  \
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82  61 years old   male               NO
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82  57 years old   male              yES
# 2  83127080-da3d-0133-c74f-0a81e8b09a82  32 years old   male               nO
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82  45 years old   Male              YES
# 4  24954a70-db98-0133-4a64-0a81e8b09a82  41 years old    Fem              yES
#
#   age_group
# 0     40_65
# 1     40_65
# 2     26_39
# 3     40_65
# 4     40_65

# %%
country_info_raw = pd.read_sql_query("SELECT * FROM country_info", engine)
country_info_raw.head()
# Out:
#                                    uuid country_code        rural
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82           AT  countryside
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82           AT        urban
# 2  83127080-da3d-0133-c74f-0a81e8b09a82           AT         city
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82           AT      Country
# 4  24954a70-db98-0133-4a64-0a81e8b09a82           AT         city

# %%
career_info_raw = pd.read_sql_query("SELECT * FROM career_info", engine)
career_info_raw.head()
# Out:
#                                    uuid dem_education_level dem_full_time_job  \
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82                  no                no
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82                high               yes
# 2  83127080-da3d-0133-c74f-0a81e8b09a82                None                no
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82                high               yes
# 4  24954a70-db98-0133-4a64-0a81e8b09a82                high               yes
#
#                 normalized_job_code
# 0                              None
# 1  861a9b9151e11362eb3c77ca914172d0
# 2                              None
# 3  049a3f3a2b5f85cb2971ba77ad66e10c
# 4  f4b2fb1aa40f661488e2782b6d57ad2f

# %%
poll_info_raw = pd.read_sql_query("SELECT * FROM poll_info", engine)
poll_info_raw.head()
# Out:
#                                    uuid  \
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82
# 2  83127080-da3d-0133-c74f-0a81e8b09a82
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82
# 4  24954a70-db98-0133-4a64-0a81e8b09a82
#
#   question_bbi_2016wave4_basicincome_awareness  \
# 0                    I know something about it
# 1                        I understand it fully
# 2          I have heard just a little about it
# 3          I have heard just a little about it
# 4          I have heard just a little about it
#
#   question_bbi_2016wave4_basicincome_vote  \
# 0                        I would not vote
# 1            I would probably vote for it
# 2                        I would not vote
# 3            I would probably vote for it
# 4            I would probably vote for it
#
#          question_bbi_2016wave4_basicincome_effect  \
# 0                                None of the above
# 1  A basic income would not affect my work choices
# 2                       ‰Û_ gain additional skills
# 3                                    ‰Û_ work less
# 4                                None of the above
#
#      question_bbi_2016wave4_basicincome_argumentsfor  \
# 0                                  None of the above
# 1  It increases appreciation for household work a...
# 2            It creates more equality of opportunity
# 3     It reduces anxiety about financing basic needs
# 4     It reduces anxiety about financing basic needs
#
#   question_bbi_2016wave4_basicincome_argumentsagainst
# 0                                  None of the above
# 1          It might encourage people to stop working
# 2  Foreigners might come to my country and take a...
# 3                                  None of the above
# 4  It is impossible to finance | It might encoura...

# %%
#  ---------- MERGED ----------

merge_1 = pd.merge(personal_info_raw, country_info_raw, how='inner', on='uuid')
merge_2 = pd.merge(merge_1, career_info_raw, how='inner', on='uuid')
tables_merged_raw = pd.merge(merge_2, poll_info_raw, how='inner', on='uuid') # ---> Dataframe merged

# %%
tables_merged_raw.rename(columns={'age': 'Age (years)'}, inplace=True)

# %%
#  ---------- Clean AGE column ----------

for i in range(len(tables_merged_raw)):
    if 'years' in tables_merged_raw.loc[i, 'Age (years)']:
        tables_merged_raw.loc[i, 'Age (years)'] = int(tables_merged_raw.loc[i, 'Age (years)'].replace(' years old', ''))
    else:
        tables_merged_raw.loc[i, 'Age (years)'] = 2016 - int(tables_merged_raw.loc[i, 'Age (years)'])

# %%
#tables_merged_raw

# %%
jobs_list = list(tables_merged_raw['normalized_job_code'].unique())
jobs_list[:10] # -----> Esto habra que cruzarlo con el df de la API con left join
# Out:
# [None,
#  '861a9b9151e11362eb3c77ca914172d0',
#  '049a3f3a2b5f85cb2971ba77ad66e10c',
#  'f4b2fb1aa40f661488e2782b6d57ad2f',
#  '27af8700f5577cec835acee2cb90a2ff',
#  'c1b670eba9ccb65e7c99f7da116d5b9c',
#  'd71c4164c99a5f9bca773e755a72f40f',
#  '2ee80cf30e2483dfe0947adc0428f8c5',
#  '897ef18a9321616495831a4b4b0c1bb2',
#  'a003702c0cea282e17967772dd83de5e']

# %%
#  ---------- API ----------

# %%
import requests

#http://api.dataatwork.org/v1/jobs?offset=46296&limit=1

# ----- Get the number of jobs -----

response = requests.get('http://api.dataatwork.org/v1/jobs?offset=0&limit=1')

json_data = response.json()

number_of_jobs = int(json_data[1]['links'][3]['href'].replace('/jobs?offset=','').replace('&limit=1',''))
number_of_requests = number_of_jobs // 500
last_request = number_of_jobs % 500

# %%
# ----- Get jsons ----- REQUEST


response_500s = [requests.get(f'http://api.dataatwork.org/v1/jobs?offset={500 * (request-1)}&limit=500') for request in range(number_of_requests)]
response_last = requests.get(f'http://api.dataatwork.org/v1/jobs?offset={number_of_jobs - last_request}&limit=500')

# %%
# ----- Get jsons ----- JSONS

json_data_500s = [response.json()[:-1] for response in response_500s]
json_data_last = response_last.json()[:-1]

# ----- Flatten and join -----
import itertools

json_data_500s_flat = list(itertools.chain(*json_data_500s))
json_data = json_data_500s_flat + json_data_last # ---->  List of all jobs 

jobs_df = pd.DataFrame(json_data)
jobs_df = jobs_df.rename(columns={'uuid': 'job_uuid'})
jobs_df.head()
# Out:
#         normalized_job_title                       parent_uuid  \
# 0          1st grade teacher  51cc95467c1844c7dc1d923265c023b2
# 1               1st pressman  96f1cf15fe5880d8660c70f0756944ab
# 2  1st pressman on web press  96f1cf15fe5880d8660c70f0756944ab
# 3                  21 dealer  4be080220c824dcb435d59ebf1c3ce80
# 4          2nd grade teacher  51cc95467c1844c7dc1d923265c023b2
#
#                        title                          job_uuid
# 0          1st Grade Teacher  26bc4486dfd0f60b3bb0d8d64e001800
# 1               1st Pressman  9be6e14491305132c175cb1781a3356c
# 2  1st Pressman On Web Press  d38d16bab3f9f25ae34ae3e2aad254d4
# 3                  21 Dealer  8576a78b5c1cae3a567ca7fd34500357
# 4          2nd Grade Teacher  a59278d7f653db37e54a270345a91a05

# %%
#  ---------- WEB SCRAPING ----------

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
url = 'https://ec.europa.eu/eurostat/statistics-explained/index.php/Glossary:Country_codes'

# %%
html = requests.get(url).content
soup = BeautifulSoup(html, 'lxml')

# %%
tables = soup.find_all('table')

# %%
countries_raw = [table.find_all('td') for table in tables]

countries_flatted = list(itertools.chain(*countries_raw))


countries = [country.text.replace('\n','') for country in countries_flatted]
countries_clean = [country for country in countries if country != '' and country != ' \xa0']
countries_clean = [re.sub('\[[0-9]\]','',country).replace('*','') for country in countries_clean]


countries_names = [country.strip() for country in countries_clean[::2]]
countries_codes = [country.replace('(','').replace(')','').strip() for country in countries_clean [1::2]]
countries_dict = {countries_codes[i]: countries_names[i] for i in range(len(countries_names))}
countries_dict['GB'] = countries_dict['UK']
countries_dict['GR'] = countries_dict['EL']

# %%
# countries_dict
# jobs_df
# tables_merged_raw

# %%
#  ---------- TODAS LAS TABLAS JUNTAS ----------

tables_merged_jobs_raw = pd.merge(tables_merged_raw, jobs_df, how='left', left_on='normalized_job_code' ,right_on='job_uuid')

tables_merged_jobs_raw['Country'] = [countries_dict[f'{country}'] for country in tables_merged_jobs_raw['country_code']]

# %%
tables_merged_jobs_raw.tail()
len(tables_merged_jobs_raw)
# Out:
# 9649

# %%
#  ---------- FILTRAR  nos quedamos con las filas que tienen trabajo ----------

filter_jobs = ~tables_merged_jobs_raw['title'].isnull()
table_merged_raw = tables_merged_jobs_raw[filter_jobs]

# table_merged_raw.tail()
len(table_merged_raw)
# Out:
# 5702

# %%
table = table_merged_raw[['Country', 'title', 'Age (years)']]
table_df = pd.DataFrame(table.groupby(['Country', 'title', 'Age (years)']).size()).reset_index().set_index('Country')

table_df.rename(columns={'title': 'Job Title', 0: 'Quantity'}, inplace=True)

table_df['Percentage'] = 100 * table_df['Quantity']/len(table_df)

table_df.head()
# Out:
#                                                  Job Title  Age (years)  \
# Country
# Austria  Automatic Data Processing Customer Liaison (AD...           31
# Austria  Automatic Data Processing Customer Liaison (AD...           40
# Austria                  Automatic Data Processing Planner           48
# Austria                  Automatic Data Processing Planner           57
# Austria  Automatic Data Processing Systems Security Spe...           27
#
#          Quantity  Percentage
# Country
# Austria         1    0.018882
# Austria         1    0.018882
# Austria         1    0.018882
# Austria         1    0.018882
# Austria         1    0.018882

# %%
# ----- Filtrar por paises -----

'Spain' in table_df.index.unique().to_list()

table_df.loc['Spain']
# Out:
#                                                  Job Title  Age (years)  \
# Country
# Spain                                Analytical Data Miner           22
# Spain    Automatic Data Processing Customer Liaison (AD...           18
# Spain    Automatic Data Processing Customer Liaison (AD...           22
# Spain    Automatic Data Processing Customer Liaison (AD...           28
# Spain    Automatic Data Processing Customer Liaison (AD...           33
# Spain    Automatic Data Processing Customer Liaison (AD...           39
# Spain    Automatic Data Processing Customer Liaison (AD...           43
# Spain    Automatic Data Processing Customer Liaison (AD...           44
# Spain    Automatic Data Processing Customer Liaison (AD...           50
# Spain    Automatic Data Processing Customer Liaison (AD...           53
# Spain    Automatic Data Processing Customer Liaison (AD...           57
# Spain                    Automatic Data Processing Planner           25
# Spain                    Automatic Data Processing Planner           31
# Spain                    Automatic Data Processing Planner           33
# Spain                    Automatic Data Processing Planner           34
# Spain                    Automatic Data Processing Planner           39
# Spain                    Automatic Data Processing Planner           45
# Spain                    Automatic Data Processing Planner           49
# Spain                    Automatic Data Processing Planner           50
# Spain                    Automatic Data Processing Planner           54
# Spain      Automatic Data Processing Planner (ADP Planner)           25
# Spain      Automatic Data Processing Planner (ADP Planner)           34
# Spain      Automatic Data Processing Planner (ADP Planner)           40
# Spain      Automatic Data Processing Planner (ADP Planner)           44
# Spain      Automatic Data Processing Planner (ADP Planner)           48
# Spain      Automatic Data Processing Planner (ADP Planner)           49
# Spain      Automatic Data Processing Planner (ADP Planner)           51
# Spain      Automatic Data Processing Planner (ADP Planner)           53
# Spain      Automatic Data Processing Planner (ADP Planner)           59
# Spain    Automatic Data Processing Systems Security Spe...           27
# ...                                                    ...          ...
# Spain                        Micro Computer Data Processor           59
# Spain    Naval Tactical Data System--Combat Information...           18
# Spain    Naval Tactical Data System--Combat Information...           40
# Spain    Naval Tactical Data System--Combat Information...           42
# Spain    Operations Officer, Afloat (Naval Tactical Dat...           40
# Spain           Oracle Database Administrator (Oracle DBA)           28
# Spain           Oracle Database Administrator (Oracle DBA)           34
# Spain           Oracle Database Administrator (Oracle DBA)           37
# Spain           Oracle Database Administrator (Oracle DBA)           42
# Spain           Oracle Database Administrator (Oracle DBA)           43
# Spain           Oracle Database Administrator (Oracle DBA)           59
# Spain           Oracle Database Administrator (Oracle DBA)           61
# Spain                                Reference Data Expert           33
# Spain                                Reference Data Expert           45
# Spain    SCADA Operator (Supervisory Control and Data A...           21
# Spain    SCADA Technician (Supervisory Control and Data...           48
# Spain                           SQL Database Administrator           42
# Spain                           SQL Database Administrator           44
# Spain                           SQL Database Administrator           48
# Spain                           SQL Database Administrator           56
# Spain                           SQL Database Administrator           61
# Spain                          Scientific Database Curator           42
# Spain                          Scientific Database Curator           46
# Spain                               Survey Data Technician           19
# Spain                            Voice and Data Technician           24
# Spain                            Voice and Data Technician           41
# Spain    Weight in Motion Field Data Collection Technician           30
# Spain    Weight in Motion Field Data Collection Technician           35
# Spain    Weight in Motion Field Data Collection Technician           37
# Spain    Weight in Motion Field Data Collection Technician           45
#
#          Quantity  Percentage
# Country
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           2    0.037764
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           2    0.037764
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           2    0.037764
# Spain           1    0.018882
# ...           ...         ...
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           4    0.075529
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
# Spain           1    0.018882
#
# [533 rows x 4 columns]
